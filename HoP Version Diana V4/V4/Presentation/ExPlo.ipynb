# %%
import pandas as pd

# %%
polestudios_overview = pd.read_csv('1_PoleStudio_Overview_Didi_2023-06-05_13-19.csv')
workshop_overview = pd.read_csv('1_Workshop_Overview_Didi_e_2023-06-05_13-19.csv')
workshop_list = pd.read_csv('1_Workshops_List_Didi_Ws_2023-06-05_13-19.csv')

all_pole_ger = pd.read_csv('pole_studios_ger_not_validated_L_S_DWO.csv')

# %%
print(polestudios_overview)
# Out:
#                      PoleStudio    PLZ                          Stadt  \
# 0         Center of Moving Arts  64625                Fabrikstraße 21
# 1          Aerial Art Poledance  66287              Holzer Straße 98
# 2                   Pura Studio  52477      Schaufenberger Straße 61
# 3           Pole Dance Beauties   6112  Edmund-von-Lippmann-Straße 9
# 4             Polefriends Halle   6108           Leipziger Straße 36
# 5   Pole Dance Palazzo Sportivo  69190       Rudolf-Diesel-Straße 54
# 6                Star Poledance  53919        Rudolf-Diesel-Straße 6
# 7                      AIRobics  22081        Holsteinischer Kamp 58
# 8         Da Becca Flow and Fit  44651             Eickeler Markt 3A
# 9         PoleRoom Braunschweig  38118              Büchnerstraße 10
# 10      Body meets Soul Leipzig   4159                  Hüfnerstraße
# 11             BALANCE Neumarkt  92318              Deininger Weg 94
# 12                    Pole Land  40227            Kölner Straße 336A
# ...

# %%
len(polestudios_overview["PoleStudio"].unique())
# Out:
# 16

# %%
len(polestudios_overview["Eversports Pole Studio Seite"].unique())
# Out:
# 16

# %%
len(workshop_overview)
# Out:
# 77

# %%
workshop_overview
# Out:
#                                         Workshop Name  \
# 0    Fortsetzung folgt Lady Marmalade Chair Dance ...
# 1    Fortsetzung folgt Azzlack Stereotyp 2 Exotic ...
# 2                          Handspring Ayesha Workshop
# 3                  Circus Kids Luftakrobatik Workshop
# 4                        Hip Hop Pole Choreo Workshop
# ..                                                ...
# 72                            High Heels Flow mit Lea
# 73               Poledance Anfänger Workshop 4 Wochen
# 74                                 Acro Yoga Workshop
# 75                                          Hoop Flow
# 76                                Einsteiger Workshop
#
#                                 Workshop Beschreibung             PoleStudio  \
# 0   Ihr wollt sie? Ihr bekommt sie!Hier kommt die ...            poda Studio
# 1   Ihr wollt sie? Ihr bekommt sie!Hier kommt die ...            poda Studio
# 2   Dein Ziel ist es den Handspring zu lernen? Ode...            poda Studio
# ...
