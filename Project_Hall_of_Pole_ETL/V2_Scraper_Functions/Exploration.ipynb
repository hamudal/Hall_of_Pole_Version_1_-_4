# %%
import pandas as pd

# %%
# workshoplist_df = pd.read_csv('poda_workshop_list')
polestudio_df = pd.read_csv('1_PoleStudio_Overview_Didi_2023-04-21_03-21.csv')

workshop_df = pd.read_csv('1_Workshop_Overview_Didi_e_2023-04-21_03-21.csv')

workshop_list_df = pd.read_csv('1_Workshops_List_Didi_Ws_2023-04-21_03-21.csv')

hop_new_df = pd.read_excel("Pole Studios_20.04_2023.xlsx")

# %%
hop_new_df["Eversports"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 253    https://www.eversports.de/sw/yoga-and-pole-art...
# 254                                                  NaN
# 255                                                  NaN
# 256                                                  NaN
# 257    https://www.eversports.be/sk/dunya-pole-dance-...
# Name: Eversports, Length: 258, dtype: object

# %%
polestudio_df
# Out:
#                     PoleStudio    PLZ            Stadt        Adresse
# 0  Yoga and Pole Art by Selina  53783  Zum Wingert 10    53783 Eitorf  \
#
#                             Pole Studio Beschreibung Start Preis
# 0  Yoga and Pole Art by Selina bietet dir Online ...     24,00 €  \
#
#   Schnupperkurspreis  Ratingscore    Reviewanzahl
# 0            24,00 €          5.0  49 Rezensionen  \
#
#                               E-Mail                               Homepage
# 0   yogaandpoleartbyselina@gmail.com  http://www.yogaandpoleartbyselina.com  \
#
#            Telefon                       Eversports Pole Studio Seite
# 0  +49 15738925807  https://www.eversports.de/s/yoga-and-pole-art-...  \
#
#                Version
# 0  2023-04-21 03:21:14

# %%
workshop_df
# Out:
#                                        Workshop Name
# 0           Shoulder Mobility 4 Wochen Intensivkurs   \
# 1  Floor Pole Shapes Online Workshop Intermediate...
# 2                Hip Mobility 4 Wochen Intensivkurs
# 3    Spinning Pole Combos Einsteiger Online Workshop
# 4          Yoga Rad Fortgeschrittene Online Workshop
# 5             Split Straddle Technik Online Workshop
# 6     Yoga Rad Online Workshop Schwerpunkt Backbends
# 7            4 Wochen Online Intensivkurs Inversions
# 8                      Atemtechniken Online Workshop
#
#                                Workshop Beschreibung
# 0  In diesem 4 Wochen Intensivkurs trainieren wir...  \
# 1  In diesem Workshop zeige ich dir unterschiedli...
# 2  In diesem 4 Wochen Intensivkurs trainieren wir...
# 3  Du machst noch nicht so lange Pole und kennst ...
# 4  Du hast bereits Yoga Erfahrung und suchst eine...
# 5  Du trainierst schon länger an deinem Spagat od...
# 6  In diesem Workshop Special zeige ich dir, wie ...
# ...

# %%
workshop_list_df
# Out:
#                                        Workshop Name PoleStudio
# 0          Shoulder Mobility (4 Wochen Intensivkurs)       Yoga  \
# 1  Floor Pole Shapes Online Workshop (Intermediat...       Yoga
# 2               Hip Mobility (4 Wochen Intensivkurs)       Yoga
# 3    Spinning Pole Combos Einsteiger Online Workshop       Yoga
# 4          Yoga Rad Fortgeschrittene Online Workshop       Yoga
# 5          Split & Straddle Technik Online Workshop        Yoga
# 6   Yoga Rad Online Workshop: Schwerpunkt Backbends        Yoga
# 7          4 Wochen Online Intensivkurs: Inversions        Yoga
# 8                     Atemtechniken Online Workshop        Yoga
#
#                         Workshop Seite Eversports              Version
# 0  https://www.eversports.de/e/workshop/uJcCoTaKv  2023-04-21 03:21:11
# 1  https://www.eversports.de/e/workshop/tx-_485PK  2023-04-21 03:21:11
# 2  https://www.eversports.de/e/workshop/69oCVwxsO  2023-04-21 03:21:11
# ...
