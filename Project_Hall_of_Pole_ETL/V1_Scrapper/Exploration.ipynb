# %%
import pandas as pd

# %%
path_workshop = r'C:\Users\hamud\Documents\Projects\Aftermath\Project HallofPole\notebooks\PoleStudio_Overview_Workshop_List\Clean\Workshop_CSV'
path_polestudio = r'C:\Users\hamud\Documents\Projects\Aftermath\Project HallofPole\notebooks\PoleStudio_Overview_Workshop_List\Clean\PoleStudio_CSV'
path_workshop_lists = r'C:\Users\hamud\Documents\Projects\Aftermath\Project HallofPole\notebooks\PoleStudio_Overview_Workshop_List\Clean\Workshop_List_CSV'

# %%
# from Workshop_Overview_clean import workshop_overview_func

# %%
workshoplist_df = pd.read_csv('workshop_list.csv')
workshop_df = pd.read_csv('workshop_overview.csv')
polestudio_df = pd.read_csv('pole_studio_overview.csv')
hallofpole_df = pd.read_csv('Eversports_1.1_Überarbeitet.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 workshoplist_df = pd.read_csv('workshop_list.csv')
#       2 workshop_df = pd.read_csv('workshop_overview.csv')
#       3 polestudio_df = pd.read_csv('pole_studio_overview.csv')
#
# File c:\Users\hamud\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\hamud\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
polestudio_df[0:1]
# Out:
#     PoleStudio    PLZ                Stadt        Adresse
# 0  poda Studio  52062  Martinstraße 10-12    52062 Aachen  \
#
#                             Pole Studio Beschreibung Start Preis
# 0  Flieg mit uns! Poda ist das größte Pole Dance ...     15,00 €  \
#
#   Schnupperkurspreis  Ratingscore    Reviewanzahl               E-Mail
# 0            15,00 €          4.9  46 Rezensionen   info@podastudio.de  \
#
#                      Homepage          Telefon              Version
# 0  https://www.podastudio.de/  +49241 95719917  2023-04-17 21:34:17

# %%
workshop_df
# Out:
#                         Workshop Name
# 0  Circus Kids Luftakrobatik Workshop  \
#
#                                Workshop Beschreibung   PoleStudio   Stadt
# 0  Für alle Kids die schon immer mal Zirkusluft s...  poda Studio  Aachen  \
#
#                                Straße       Datum          Uhrzeit   Dauer
# 0  10-12 Martinstraße Innenhof, 52062  03.12.2023  12:00-13:30 Uhr  90 min  \
#
#    Level Trainer                               Trainer Beschreibung
# 0      0    Emmy  Kreativ, offen, Allrounder & Tattoo lover.\nEm...  \
#
#             Preis                          Workshop Everest Seite
# 0  Preis: 35,00 €  https://www.eversports.de/e/workshop/RPiNq9mm6  \
#
#                PoleStudio Eversports Seite              Version
# 0  https://www.eversports.de/s/poda-studio  2023-04-17 22:37:09

# %%
hallofpole_df[0:5]
# Out:
#                                                 Name
# 0                      Atemtechniken Online Workshop  \
# 1   Bedroom Burlesque mit Lady Lou THEMA: tba ONLINE
# 2                     Exotic Dance mit Becky* ONLINE
# 3  Exotic Pole Choreo | Externer Beginner Worksho...
# 4  Floor Pole Shapes Online Workshop (Intermediat...
#
#                                          Webseite       Preis
# 0  https://www.eversports.de/e/workshop/v4j4ZnWFW  ab 44,00 €  \
# 1  https://www.eversports.de/e/workshop/cGbDoasJb  ab 40,00 €
# 2  https://www.eversports.de/e/workshop/xv2_PAISE  ab 40,00 €
# 3  https://www.eversports.de/e/workshop/ocz15aUrk  ab 45,00 €
# 4  https://www.eversports.de/e/workshop/tx-_485PK  ab 44,00 €
#
#                Kategorie                            PoleStudio          Stadt
# 0                Special  14d3a173-6611-40bb-beba-022dd23765ed         Online  \
# 1        Dance (no pole)  aff95b8f-66f1-49f0-997e-ff70484a05c7         Berlin
# ...

# %%
didi_pages = hallofpole_df["Webseite"]
len(didi_pages)
didi_pages
# Out:
# 0     https://www.eversports.de/e/workshop/v4j4ZnWFW
# 1     https://www.eversports.de/e/workshop/cGbDoasJb
# 2     https://www.eversports.de/e/workshop/xv2_PAISE
# 3     https://www.eversports.de/e/workshop/ocz15aUrk
# 4     https://www.eversports.de/e/workshop/tx-_485PK
# 5     https://www.eversports.de/e/workshop/nDyryrDzB
# 6     https://www.eversports.de/e/workshop/WIiSb5dg1
# 7     https://www.eversports.de/e/workshop/OjGR_JBOx
# 8     https://www.eversports.de/e/workshop/8FXiuS8_E
# 9     https://www.eversports.de/e/workshop/bzRPpiHhj
# 10    https://www.eversports.de/e/workshop/0CWbuWeCP
# 11    https://www.eversports.de/e/workshop/PG7A7dCx6
# 12    https://www.eversports.de/e/workshop/R3VflUB-G
# 13    https://www.eversports.de/e/workshop/6HjnBPeOE
# 14    https://www.eversports.de/e/workshop/vShOvMLtb
# 15    https://www.eversports.de/e/workshop/7rFKxizij
# 16    https://www.eversports.de/e/workshop/XVTRcbEDY
# 17    https://www.eversports.de/e/workshop/uLOMWc_ox
# ...

# %%
workshoplist_df[1:2]
# Out:
#                         Workshop Name
# 1  Circus Kids Luftakrobatik Workshop  \
#
#                         Workshop Seite Eversports              Version
# 1  https://www.eversports.de/e/workshop/x1w0Mq3Y7  2023-04-18 00:12:47

# %%
url_list = workshoplist_df["Workshop Seite Eversports"]
url_list
# Out:
# 0     https://www.eversports.de/e/workshop/x31ysLeOS
# 1     https://www.eversports.de/e/workshop/x1w0Mq3Y7
# 2     https://www.eversports.de/e/workshop/xFwPArnAH
# 3     https://www.eversports.de/e/workshop/Sh6fqaIks
# 4     https://www.eversports.de/e/workshop/feME-_7tG
# 5     https://www.eversports.de/e/workshop/dCR2PVd05
# 6     https://www.eversports.de/e/workshop/nb8_WV2wH
# 7     https://www.eversports.de/e/workshop/cDPxswQQp
# 8     https://www.eversports.de/e/workshop/xo_EQbOQn
# 9     https://www.eversports.de/e/workshop/HGkpQ9uAJ
# 10    https://www.eversports.de/e/workshop/Bz5neTPTa
# 11    https://www.eversports.de/e/workshop/3zdELX6G_
# 12    https://www.eversports.de/e/workshop/tUZ-pbNF0
# 13    https://www.eversports.de/e/workshop/5u5RfrpDC
# 14    https://www.eversports.de/e/workshop/RPiNq9mm6
# Name: Workshop Seite Eversports, dtype: object

# %%
df_1 = pd.read_csv(f"{path_workshop}/Atemtechniken Online Workshop.csv")

df_3 = pd.read_csv(f"{path_workshop}/Floor Pole Shapes Online Workshop (Intermediate Level).csv")

df_5 = pd.read_csv(f"{path_workshop}/Lap Dance & Strip 'n' Tease ONLINE.csv")

# %%
result_df = pd.concat([df_1, df_3, df_5], ignore_index=True)
result_df
# Out:
#                                        Workshop Name
# 0                      Atemtechniken Online Workshop  \
# 1  Floor Pole Shapes Online Workshop (Intermediat...
# 2                 Lap Dance & Strip 'n' Tease ONLINE
#
#                                Workshop Beschreibung
# 0  Inhalte des Workshops:Aufbau des Workshops: De...  \
# 1  In diesem Workshop zeige ich dir unterschiedli...
# 2  Lap Dance & Strip 'n' Tease WorkshopIm ersten ...
#
#                     PoleStudio  Stadt  Straße       Datum          Uhrzeit
# 0  Yoga and Pole Art by Selina      0       0  16.07.2023  18:00-19:30 Uhr  \
# 1  Yoga and Pole Art by Selina      0       0  01.05.2023  11:00-12:30 Uhr
# 2        Schönheitstanz Studio      0       0  23.04.2023  18:15-20:45 Uhr
#
#     Dauer         Level Trainer
# 0  90 min      Anfänger  Selina  \
# 1  90 min  Intermediate  Selina
# 2  50 min    Alle Level   Agata
#
#                                 Trainer Beschreibung              Preis
# ...

# %%
print(result_df["PoleStudio Eversports Seite"][0])
# Out:
# https://www.eversports.de/s/yoga-and-pole-art-by-selina

# %%
df_1_studio = pd.read_csv(f"{path_polestudio}/poda Studio.csv")

df_3_studio = pd.read_csv(f"{path_polestudio}/Schönheitstanz Studio.csv")

df_5_studio = pd.read_csv(f"{path_polestudio}/Yoga and Pole Art by Selina.csv")

# %%
result_df = pd.concat([df_1_studio, df_3_studio, df_5_studio], ignore_index=True)
result_df
# Out:
#                     PoleStudio    PLZ                Stadt        Adresse
# 0                  poda Studio  52062  Martinstraße 10-12    52062 Aachen  \
# 1        Schönheitstanz Studio  10117     Charitestraße 4    10117 Berlin
# 2  Yoga and Pole Art by Selina  53783      Zum Wingert 10    53783 Eitorf
#
#                             Pole Studio Beschreibung Start Preis
# 0  Flieg mit uns! Poda ist das größte Pole Dance ...     15,00 €  \
# 1  Das Schönheitstanzstudio bringt allen Teilnehm...     10,00 €
# 2  Yoga and Pole Art by Selina bietet dir Online ...     24,00 €
#
#   Schnupperkurspreis  Ratingscore    Reviewanzahl
# 0            15,00 €          4.9  46 Rezensionen  \
# 1            10,00 €          5.0  33 Rezensionen
# 2            24,00 €          5.0  49 Rezensionen
#
#                               E-Mail                               Homepage
# 0                 info@podastudio.de             https://www.podastudio.de/  \
# ...

# %%
df_3_studio_list = pd.read_csv(f"{path_workshop_lists}/poda_workshop_list.csv")

df_5_studio_list = pd.read_csv(f"{path_workshop_lists}/schön_workshop_list.csv")

# %%
df_3_studio_list
# Out:
#                                         Workshop Name
# 0                               Hip Hop Pole Workshop  \
# 1                  Circus Kids Luftakrobatik Workshop
# 2   Pole Dance Probestunde *Poda Birthday Special*...
# 3           Pole Fitness *Poda Birthday Special* Free
# 4          Twerk & Chair *Poda Birthday Special* Free
# 5                     Hard Style Exotic Pole Workshop
# 6                  Circus Kids Luftakrobatik Workshop
# 7   *Fortsetzung folgt...* Lady Marmalade Chair Da...
# 8   *Fortsetzung folgt...* Azzlack Stereotyp 2 - E...
# 9                  Circus Kids Luftakrobatik Workshop
# 10                 Circus Kids Luftakrobatik Workshop
# 11                 Circus Kids Luftakrobatik Workshop
# 12                 Circus Kids Luftakrobatik Workshop
# 13                 Circus Kids Luftakrobatik Workshop
# 14                 Circus Kids Luftakrobatik Workshop
#
#                          Workshop Seite Eversports              Version
# ...

# %%
df_5_studio_list
# Out:
#                                         Workshop Name
# 0   Pole Dance Fortgeschrittene 1 Teil 2 (zweistün...  \
# 1   Burlesque-Workshop "sexy Floorwork" mit Tania ...
# 2               Lap Dance & Strip 'n' Tease Workshop
# 3                  Lap Dance & Strip 'n' Tease ONLINE
# 4   Pole Embodiment (und traumasensibles Training)...
# 5                             Pole Poetics - Yara Mar
# 6                             Pole Poetics - Yara Mar
# 7                             Pole Poetics - Yara Mar
# 8                         Pole Dance Anfänger 1 Kurs
# 9   Burlesque Anfängerworkshop mit Lady Lou ( Zwei...
# 10            Burlesque Anfängerworkshop mit Lady Lou
# 11                            Lap Dance Teil 2 ONLINE
# 12                                   Lap Dance Teil 2
# 13  Selbstverteidigung speziell für Frauen Anfänge...
# 14         Jenna Wilsons High Heel Walk & Dance Kurs
# 15                                       Twerk Basics
# ...
