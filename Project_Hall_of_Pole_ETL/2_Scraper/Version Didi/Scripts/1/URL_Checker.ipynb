# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
not_validated_urls
# Out:
#             City                                       Image Source  \
# 0         Aachen  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 1         Aachen  https://files.eversports.com/0aed1787-d224-486...
# 2      Abensberg  https://files.eversports.com/a73d40e1-eaf2-430...
# 3      Abensberg  https://files.eversports.com/9b5f6e3a-5ec8-45f...
# 4         Achern  https://files.eversports.com/0fe3af8e-230c-4d1...
# ..           ...                                                ...
# 126  Rheinfelden  https://files.eversports.com/ada68e9c-7bfc-4ce...
# 127  Rheinfelden  https://files.eversports.com/596619e4-9146-413...
# 128  Rheinfelden  https://files.eversports.com/b42766e6-b1ea-420...
# 129        Soest  https://files.eversports.com/eca53eeb-765a-4f6...
# 130        Soest  https://files.eversports.com/2dea9cce-e138-4a2...
#
#                   Business Name  Rating     Number of Reviews  \
# 0                   poda Studio  rating  4,9 (47 Rezensionen)
# ...

# %%
not_validated_urls = pd.read_csv("all_pole_studios_germany_&_Didi_not_validated_urls.csv")

# %%
url_list = not_validated_urls["Studio Workshop Url: SW"]

# %%
def is_url_valid(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return True
        else:
            return False
    except requests.exceptions.RequestException as e:
        print(f"Error while checking URL: {url}\nError: {e}")
        return False

# %%
valid_urls = []

for index, url in enumerate(url_list):
    print(f"Processing URL {index + 1}/{len(url_list)}: {url}")
    if is_url_valid(url):
        valid_urls.append(url)
        print(f"URL {url} is valid.")
    else:
        print(f"URL {url} is not valid.")
    print("\n")
# Out:
# Processing URL 1/131: https://www.eversports.de/sw/poda-studio
# URL https://www.eversports.de/sw/poda-studio is valid.
#
#
# Processing URL 2/131: https://www.eversports.de/sw/pura-studio
# URL https://www.eversports.de/sw/pura-studio is valid.
#
#
# Processing URL 3/131: https://www.eversports.de/sw/polesition-regensburg
# URL https://www.eversports.de/sw/polesition-regensburg is valid.
#
#
# Processing URL 4/131: https://www.eversports.de/sw/sportheim-abensberg
# URL https://www.eversports.de/sw/sportheim-abensberg is valid.
#
#
# Processing URL 5/131: https://www.eversports.de/sw/körperformfabrik-gbr
# URL https://www.eversports.de/sw/körperformfabrik-gbr is not valid.
#
#
# Processing URL 6/131: https://www.eversports.de/sw/soultide
# URL https://www.eversports.de/sw/soultide is valid.
#
#
# Processing URL 7/131: https://www.eversports.de/sw/feel-good-factory:-pole-•-stretch-•-fly
# URL https://www.eversports.de/sw/feel-good-factory:-pole-•-stretch-•-fly is not valid.
#
#
# ...

# %%
valid_urls_df = pd.DataFrame(valid_urls, columns=["Valid_URL"])

# assuming the URL column is named 'URL'
valid_urls_df = valid_urls_df.drop_duplicates(subset=['Valid_URL'])
valid_urls_df
# Out:
#                                             Valid_URL
# 0            https://www.eversports.de/sw/poda-studio
# 1            https://www.eversports.de/sw/pura-studio
# 2   https://www.eversports.de/sw/polesition-regens...
# 3    https://www.eversports.de/sw/sportheim-abensberg
# 4               https://www.eversports.de/sw/soultide
# ..                                                ...
# 82  https://www.eversports.de/sw/tanzschule-poleda...
# 83           https://www.eversports.de/sw/kaifu-lodge
# 84  https://www.eversports.de/sw/flow-fusion-pole-...
# 85            https://www.eversports.de/sw/polewirbel
# 86            https://www.eversports.de/sw/poleaddict
#
# [87 rows x 1 columns]

# %%
# Filter by a condition on a column
filtered_df = valid_urls_df[valid_urls_df['Valid_URL'].str.contains('https://www.eversports.de/sw/')]

# Print the filtered DataFrame
print(filtered_df)
# Out:
#                                             Valid_URL
# 0            https://www.eversports.de/sw/poda-studio
# 1            https://www.eversports.de/sw/pura-studio
# 2   https://www.eversports.de/sw/polesition-regens...
# 3    https://www.eversports.de/sw/sportheim-abensberg
# 4               https://www.eversports.de/sw/soultide
# ..                                                ...
# 82  https://www.eversports.de/sw/tanzschule-poleda...
# 83           https://www.eversports.de/sw/kaifu-lodge
# 84  https://www.eversports.de/sw/flow-fusion-pole-...
# 85            https://www.eversports.de/sw/polewirbel
# 86            https://www.eversports.de/sw/poleaddict
#
# [87 rows x 1 columns]

# %%
filtered_df.to_csv("all_pole_studios_germany_&_Didi_valid_urls.csv", index=False)
