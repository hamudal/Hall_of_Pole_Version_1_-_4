# %%
import pandas as pd

# %%
pole_studio_overview = pd.read_csv('1_PoleStudio_Overview_Didi_2023-05-03_19-32.csv')
pole_workshop_overview = pd.read_csv('1_Workshop_Overview_Didi_e_2023-05-03_19-32.csv')
pole_workshop_list = pd.read_csv('1_Workshops_List_Didi_Ws_2023-05-03_19-32.csv')

hall_of_pole_og = pd.read_excel('Pole Studios.xlsx')

# %%
hall_of_pole_og.columns
# Out:
# Index(['Eversports', 'Land', 'Pole Studio', 'Adresse', 'PLZ', 'Stadt',
#        'Telefonnummer', 'E-Mail-Adresse', 'Webseite', 'Facebook', 'Instagram',
#        'Art', 'Angebot', 'Beschreibung'],
#       dtype='object')

# %%
pole_workshop_overview.columns
# Out:
# Index(['Workshop Name', 'Workshop Beschreibung', 'PoleStudio', 'Stadt',
#        'Straße', 'Datum', 'Uhrzeit', 'Dauer', 'Level', 'Trainer',
#        'Trainer Beschreibung', 'Preis', 'Workshop Everest Seite',
#        'PoleStudio Eversports Seite', 'Version'],
#       dtype='object')

# %%
len(hall_of_pole_og["Pole Studio"].unique())
hall_of_pole_og
# Out:
#                                             Eversports Land  \
# 0    keine Einteilung - https://www.eversports.de/s...   DE
# 1    keine Einteilung - https://www.eversports.de/s...   DE
# 2    keine Einteilung - https://www.eversports.de/s...   DE
# 3    keine Einteilung - https://www.eversports.ch/s...   DE
# 4    keine Einteilung - https://www.eversports.de/s...   DE
# ..                                                 ...  ...
# 268  https://www.eversports.de/sw/yoga-and-pole-art...   DE
# 269  https://www.eversports.be/sk/dunya-pole-dance-...   BE
# 270  keine Einteilung -  https://www.eversports.de/...   DE
# 271                                                NaN  NaN
# 272                                  Stand: 27.04.2023  NaN
#
#                      Pole Studio  \
# 0                 Janine Hollung
# 1             pure body concepts
# 2     Anni's Pole-Dance Uetersen
# 3                        SPIN-UP
# 4                Polefly Academy
# ..                           ...
# ...

# %%
pole_workshop_overview.rename(
    columns={'Workshop Name': 'Workshop Name',
             'Workshop Beschreibung': 'Workshop Name' ,                        
             'PoleStudio': 'Workshop Name'  ,                       
             'Stadt': 'Workshop Name' ,                      
             'Straße': 'Workshop Name' , 
             'Uhrzeit': 'Workshop Name' ,
             'Dauer': 'Workshop Name' ,
             'Level': 'Workshop Name',
             'Trainer': 'Workshop Name'  ,
             'Trainer Beschreibung': 'Workshop Name' ,
             'Preis': 'Workshop Name' ,
             'Workshop Everest Seite': 'Workshop Name',
             'PoleStudio Eversports Seite': 'Workshop Name',  
             'Version': 'Workshop Name' 
             


                                       }, inplace=True)

# %%
pole_workshop_overview
# Out:
#                                         Workshop Name  \
# 0                  Circus Kids Luftakrobatik Workshop
# 1   Pole Dance Probestunde Poda Birthday Special Free
# 2             Pole Fitness Poda Birthday Special Free
# 3              Twerk Chair Poda Birthday Special Free
# 4                     Hard Style Exotic Pole Workshop
# ..                                                ...
# 92                                    Leg Flexibility
# 93            WORKSHOP Easy Spinning Beautiful Shapes
# 94                                     Grundkurs Yoga
# 95                            KAKAOZEREMONIE mit Josi
# 96                                     Grundkurs Yoga
#
#                                 Workshop Beschreibung  \
# 0   Für alle Kids die schon immer mal Zirkusluft s...
# 1   It's Poda 8. Birthday!!!Alle Kurse sind heute ...
# 2   It's Poda 8. Birthday!!!Alle Kurse sind heute ...
# 3   It's Poda 8. Birthday!!!Alle Kurse sind heute ...
# ...
