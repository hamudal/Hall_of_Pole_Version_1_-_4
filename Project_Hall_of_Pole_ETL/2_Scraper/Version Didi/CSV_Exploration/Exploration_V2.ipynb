# %%
import pandas as pd

# %%
polestudio_df = pd.read_csv('1_PoleStudio_Overview_Didi.csv')
workshop_df = pd.read_csv('1_Workshop_Overview_Didi_e.csv')
workshop_list_df = pd.read_csv('1_Workshops_List_Didi_Ws.csv')

hop_new_df = pd.read_excel("Pole Studios_20.04_2023.xlsx")
all_pole_ger = pd.read_csv("all_pole_studios_germany.csv")
valid_urls_ger_cl = pd.read_csv("valid_urls_ger_cl.csv")


valid_url_polestudio_df = pd.read_csv('1_PoleStudio_Overview_Didi_2023-05-02_22-08.csv')
valid_url_workshop_df = pd.read_csv('1_Workshop_Overview_Didi_e_2023-05-02_22-08.csv')
valid_url_workshop_list_df = pd.read_csv('1_Workshops_List_Didi_Ws_2023-05-02_22-08.csv')

# %%
valid_url_polestudio_df
# Out:
#                      PoleStudio    PLZ                          Stadt  \
# 0                   Pura Studio  52477      Schaufenberger Straße 61
# 1              BALANCE Neumarkt  92318              Deininger Weg 94
# 2   Yoga and Pole Art by Selina  53783                Zum Wingert 10
# 3                 Pole Paradise  50739     Ravensburgerstraße 110-112
# 4                      AIRobics  22081        Holsteinischer Kamp 58
# 5          Ramonas Tanzschmiede  45886        Ückendorfer Straße 121
# 6                  PoleCreation  87435        Immenstädter Straße 11
# 7                     Pole Land  40227            Kölner Straße 336A
# 8       Niyaha Yoga Susann Kind  98617         Eduard-Fritze-Straße 5
# 9         Center of Moving Arts  64625                Fabrikstraße 21
# 10        PoleRoom Braunschweig  38118              Büchnerstraße 10
# 11                POLEDANCE NRW  40237           Rethelstraße 28 Hof
# ...

# %%
valid_url_workshop_df
# Out:
#                          Workshop Name  \
# 0            Silk Mini Choreo Beg Int
# 1        Elegant Pole Combo Beginners
# 2            Musical Dance All Levels
# 3           Pole Power Tricks Int Adv
# 4         Sexy Pole Choreo All Levels
# ..                                 ...
# 91  Circus Kids Luftakrobatik Workshop
# 92  Circus Kids Luftakrobatik Workshop
# 93  Circus Kids Luftakrobatik Workshop
# 94  Circus Kids Luftakrobatik Workshop
# 95  Circus Kids Luftakrobatik Workshop
#
#                                 Workshop Beschreibung   PoleStudio    Stadt  \
# 0   In diesem Workshop lernst du eine tolle Choreo...     AIRobics  Hamburg
# 1   In diesem Workshop lernst du eine elegante Com...     AIRobics  Hamburg
# 2   In diesem Workshop lernst du eine coole Choreo...     AIRobics  Hamburg
# 3   In diesem Workshop lernst du coole Power Trick...     AIRobics  Hamburg
# 4   In diesem Workshop lernst du eine sexy Choreog...     AIRobics  Hamburg
# ...

# %%
valid_url_workshop_list_df
# Out:
#                          Workshop Name PoleStudio  \
# 0         Silk Mini Choreo (Beg./Int.)   AIRobics
# 1       Elegant Pole Combo (Beginners)   AIRobics
# 2           Musical Dance (All Levels)   AIRobics
# 3        Pole Power Tricks (Int./Adv.)   AIRobics
# 4        Sexy Pole Choreo (All Levels)   AIRobics
# ..                                 ...        ...
# 91  Circus Kids Luftakrobatik Workshop       poda
# 92  Circus Kids Luftakrobatik Workshop       poda
# 93  Circus Kids Luftakrobatik Workshop       poda
# 94  Circus Kids Luftakrobatik Workshop       poda
# 95  Circus Kids Luftakrobatik Workshop       poda
#
#                          Workshop Seite Eversports              Version
# 0   https://www.eversports.de/e/workshop/QaE6rQp4-  2023-05-02 22:08:03
# 1   https://www.eversports.de/e/workshop/5D4VyOGRg  2023-05-02 22:08:03
# 2   https://www.eversports.de/e/workshop/N5How40JW  2023-05-02 22:08:03
# 3   https://www.eversports.de/e/workshop/9W9Yd45l6  2023-05-02 22:08:03
# ...

# %%
all_pole_ger[:3]
# Out:
#         City                                       Image Source  \
# 0     Aachen  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 1     Aachen  https://files.eversports.com/0aed1787-d224-486...
# 2  Abensberg  https://files.eversports.com/a73d40e1-eaf2-430...
#
#            Business Name  Rating     Number of Reviews  \
# 0            poda Studio  rating  4,9 (47 Rezensionen)
# 1            Pura Studio  rating    5 (60 Rezensionen)
# 2  Polesition Regensburg  rating  4,9 (27 Rezensionen)
#
#                                           Categories  \
# 0  ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
# 1  ['Yoga', 'Poledance', 'Massage', 'Stretching',...
# 2  ['Pilates', 'Tanzen', 'Poledance', 'Aerial Yog...
#
#                                     Address
# 0         Martinstraße 10-12 , 52062 Aachen
# 1  Schaufenberger Straße 61 , 52477 Alsdorf
# 2          Rebhuhnstraße 4, 93326 Abensberg

# %%
all_pole_ger["Business Name"]
# Out:
# 0                              poda Studio
# 1                              Pura Studio
# 2                    Polesition Regensburg
# 3                      Sportheim Abensberg
# 4                     Körperformfabrik GbR
#                       ...
# 791                         Star Poledance
# 792                              Pole Arts
# 793                     Pole Werk by Nelly
# 794    Pole Faction - Pole Dance & Fitness
# 795                  Center of Moving Arts
# Name: Business Name, Length: 796, dtype: object

# %%
valid_urls_ger_cl
# Out:
#                                             Valid_URL
# 0   https://www.eversports.de/sw/a-heart-for-poled...
# 1               https://www.eversports.de/sw/airobics
# 2   https://www.eversports.de/sw/aerial-art-poledance
# 3          https://www.eversports.de/sw/aerial-circus
# 4            https://www.eversports.de/sw/aerial-loft
# 5       https://www.eversports.de/sw/balance-neumarkt
# 6   https://www.eversports.de/sw/body-meets-soul-l...
# 7   https://www.eversports.de/sw/css-aerial-dance-...
# 8   https://www.eversports.de/sw/center-of-moving-...
# 9   https://www.eversports.de/sw/da-becca-flow-and...
# 10  https://www.eversports.de/sw/niyaha-yoga-susan...
# 11         https://www.eversports.de/sw/poledance-nrw
# 12   https://www.eversports.de/sw/pole-dance-beauties
# 13  https://www.eversports.de/sw/pole-dance-palazz...
# 14             https://www.eversports.de/sw/pole-land
# 15         https://www.eversports.de/sw/pole-paradise
# ...

# %%
hop_new_df[10:13]
# Out:
#                                            Eversports  \
# 10  https://www.eversports.nl/sw/aerial-studio-arnhem
# 11            https://www.eversports.de/sw/aerialflow
# 12              https://www.eversports.de/sw/airobics
#
#                                Pole Studio  \
# 10                    Aerial Studio Arnhem
# 11                              aerialflow
# 12  AIRobics - Pole & Aerial Dance Hamburg
#
#                                               Adresse      PLZ          Stadt  \
# 10  {"formatted":"Boulevard Heuvelink 104, 6828 KT...      NaN            NaN
# 11  {"formatted":"Pfefferackerstraße 2a, 45894 Gel...  45894.0  Gelsenkirchen
# 12                                                NaN  22081.0        Hamburg
#
#     Telefonnummer      E-Mail-Adresse                Webseite  \
# 10            NaN                 NaN                     NaN
# 11  0209 88000403  info@aerialflow.de  https://aerialflow.de/
# 12   015117626559   dance@airobics.de    https://airobics.de/
#
# ...

# %%
len(hop_new_df["Eversports"])
# Out:
# 258

# %%
polestudio_df
# Out:
#                              PoleStudio    PLZ                       Stadt  \
# 0                            aerialflow  45894      Pfefferackerstraße 2A
# 1                              AIRobics  22081     Holsteinischer Kamp 58
# 2              Annaconda Pole & Fitness  50827      Venloer Straße 601-603
# 3                      BALANCE Neumarkt  92318           Deininger Weg 94
# 4                 Da Becca Flow and Fit  44651          Eickeler Markt 3A
# 5   Flexx Arts - Aerial Dance & Fitness  87700           Rostocker Weg 14
# 6                              La Belle  30853               Marktplatz 4
# 7                         Pole Paradise  50739  Ravensburgerstraße 110-112
# 8         Polea - Pole and Aerial Dance  55257    Budenheimer Parkallee 5
# 9                             Polearize  44793               Rottstraße 6
# 10                         PoleathletiX  29227         Industriestraße 10
# 11                         PoleCreation  87435     Immenstädter Straße 11
# ...

# %%
workshop_df
# Out:
#                                          Workshop Name  \
# 0               Aerial Yoga Alle Level 120 Min 49 p P
# 1    Exotic Pole Choreo Externer Beginner Workshop ...
# 2       Teens Circus Luftakrobatik für Teenies 35 p P
# 3                      Aerial Yoga Stretch All Levels
# 4                      Backbend Stretching All Levels
# ..                                                 ...
# 387           Shoulder Mobility 4 Wochen Intensivkurs
# 388    Spinning Pole Combos Einsteiger Online Workshop
# 389             Split Straddle Technik Online Workshop
# 390          Yoga Rad Fortgeschrittene Online Workshop
# 391     Yoga Rad Online Workshop Schwerpunkt Backbends
#
#                                  Workshop Beschreibung  \
# 0    Aerial Yoga kombiniert Elemente aus der Luftar...
# 1    The course consists of a warm-up for exotic da...
# 2    Im Frühling möchten wir den Jung-Akrobatinnen ...
# 3    In diesem Workshop wird fleißig der ganze Körp...
# ...

# %%
workshop_list_df["PoleStudio"].unique()
# Out:
# array(['aerialflow', 'AIRobics', 'Annaconda', 'BALANCE', 'Da', 'Flexx',
#        'La', 'Pole', 'Polea', 'Polearize', 'PoleathletiX', 'PoleCreation',
#        'POLEDANCE', 'PoleRoom', 'Pure', 'Royal', 'schwerelos',
#        'Schönheitstanz', 'Seemannsbraut', 'Star', 'Vertical', 'Yoga'],
#       dtype=object)
