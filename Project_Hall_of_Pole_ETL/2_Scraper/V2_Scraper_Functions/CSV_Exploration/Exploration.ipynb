# %%
import pandas as pd

# %%
polestudio_df = pd.read_csv('1_PoleStudio_Overview_Didi_2023-04-27_15-05.csv')

workshop_df = pd.read_csv('1_Workshop_Overview_Didi_e_2023-04-27_15-05.csv')

workshop_list_df = pd.read_csv('1_Workshops_List_Didi_Ws_2023-04-27_15-05.csv')

hop_new_df = pd.read_excel("Pole Studios_20.04_2023.xlsx")

# %%
hop_new_df.head(4)
# Out:
#   Eversports            Pole Studio  \
# 0        NaN    360 Grad Soulsports
# 1        NaN  a heart for poledance
# 2        NaN        Academy of Pole
# 3        NaN     Activo Polefitness
#
#                                              Adresse      PLZ  \
# 0  {"formatted":"Aurelienstraße 12, 04177 Leipzig...   4177.0
# 1  {"formatted":"Nußbaumer Str. 6, 51469 Bergisch...  51469.0
# 2                   Gewerbestr. 7, 57258 Freudenberg  57258.0
# 3  {"formatted":"Herzogsfreudenweg 16, 53125 Bonn...  53125.0
#
#                Stadt  Telefonnummer              E-Mail-Adresse  \
# 0            Leipzig  0176 24270692       info@360soulsports.de
# 1  Bergisch Gladbach            NaN  info@aheartforpoledance.de
# 2        Freudenberg   017642095647       info@academyofpole.de
# 3               Bonn  01523 3620390       webmaster@activo.info
#
#                              Webseite  \
# 0           https://360soulsports.de/
# 1  https://www.aheartforpoledance.de/
# ...

# %%
hop_new_df["Eversports"].tail(4)
# Out:
# 254                                                  NaN
# 255                                                  NaN
# 256                                                  NaN
# 257    https://www.eversports.be/sk/dunya-pole-dance-...
# Name: Eversports, dtype: object

# %%
polestudio_df
# Out:
#               PoleStudio    PLZ                Stadt        Adresse  \
# 0            poda Studio  52062  Martinstraße 10-12    52062 Aachen
# 1  Schönheitstanz Studio  10117     Charitestraße 4    10117 Berlin
#
#                             Pole Studio Beschreibung Start Preis  \
# 0  Flieg mit uns! Poda ist das größte Pole Dance ...     15,00 €
# 1  Das Schönheitstanzstudio bringt allen Teilnehm...     10,00 €
#
#   Schnupperkurspreis  Ratingscore    Reviewanzahl                      E-Mail  \
# 0            15,00 €          4.9  47 Rezensionen          info@podastudio.de
# 1            10,00 €          5.0  33 Rezensionen   studio@schoenheitstanz.de
#
#                      Homepage           Telefon  \
# 0  https://www.podastudio.de/   +49241 95719917
# 1  https://schoenheitstanz.de  +49 016099746437
#
#                         Eversports Pole Studio Seite              Version
# 0            https://www.eversports.de/s/poda-studio  2023-04-27 15:06:04
# ...

# %%
workshop_df
# Out:
#                                         Workshop Name  \
# 0                               Hip Hop Pole Workshop
# 1                  Circus Kids Luftakrobatik Workshop
# 2   Pole Dance Probestunde Poda Birthday Special Free
# 3             Pole Fitness Poda Birthday Special Free
# 4              Twerk Chair Poda Birthday Special Free
# 5                     Hard Style Exotic Pole Workshop
# 6                  Circus Kids Luftakrobatik Workshop
# 7    Fortsetzung folgt Lady Marmalade Chair Dance ...
# 8    Fortsetzung folgt Azzlack Stereotyp 2 Exotic ...
# 9                  Circus Kids Luftakrobatik Workshop
# 10                 Circus Kids Luftakrobatik Workshop
# 11                 Circus Kids Luftakrobatik Workshop
# 12                 Circus Kids Luftakrobatik Workshop
# 13                 Circus Kids Luftakrobatik Workshop
# 14                 Circus Kids Luftakrobatik Workshop
# 15  Pole Embodiment und traumasensibles Training m...
# ...

# %%
workshop_list_df
# Out:
#                                         Workshop Name      PoleStudio  \
# 0                               Hip Hop Pole Workshop            poda
# 1                  Circus Kids Luftakrobatik Workshop            poda
# 2   Pole Dance Probestunde *Poda Birthday Special*...            poda
# 3           Pole Fitness *Poda Birthday Special* Free            poda
# 4          Twerk & Chair *Poda Birthday Special* Free            poda
# 5                     Hard Style Exotic Pole Workshop            poda
# 6                  Circus Kids Luftakrobatik Workshop            poda
# 7   *Fortsetzung folgt...* Lady Marmalade Chair Da...            poda
# 8   *Fortsetzung folgt...* Azzlack Stereotyp 2 - E...            poda
# 9                  Circus Kids Luftakrobatik Workshop            poda
# 10                 Circus Kids Luftakrobatik Workshop            poda
# 11                 Circus Kids Luftakrobatik Workshop            poda
# ...
