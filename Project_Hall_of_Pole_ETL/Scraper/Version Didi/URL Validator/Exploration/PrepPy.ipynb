# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

import re

# %%
all_cities_df = pd.read_csv('all_pole_studios_germany.csv')
all_cities_df.head(20)
# Out:
#             City                                       Image Source  \
# 0         Aachen  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 1         Aachen  https://files.eversports.com/0aed1787-d224-486...
# 2      Abensberg  https://files.eversports.com/a73d40e1-eaf2-430...
# 3      Abensberg  https://files.eversports.com/9b5f6e3a-5ec8-45f...
# 4         Achern  https://files.eversports.com/0fe3af8e-230c-4d1...
# 5     Ahrensburg  https://files.eversports.com/fc2ddda9-5ed5-49e...
# 6     Ahrensburg  https://files.eversports.com/aa909fae-006d-483...
# 7     Ahrensburg  https://files.eversports.com/592e5cf9-c2d9-40b...
# 8     Ahrensburg  https://files.eversports.com/8cbb2bc4-7116-4df...
# 9        Aichtal  https://files.eversports.com/acd0bdf0-7c65-408...
# 10       Aichtal  https://files.eversports.com/de88c9ad-d060-4f5...
# 11       Aichtal  https://files.eversports.com/651383bb-513d-413...
# 12          Aken  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 13          Aken  https://files.eversports.com/0aed1787-d224-486...
# 14       Alsdorf  https://files.eversports.com/0aed1787-d224-486...
# 15       Alsdorf  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 16     Altenberg  https://files.eversports.com/c902a4a3-458a-456...
# 17  Altenkirchen  https://files.eversports.com/ce4d6229-b12d-4d2...
# 18    Altensteig              /static/media/icon-white.929e2590.svg
# 19     Altötting  https://files.eversports.com/e985ab77-98b5-45e...
#
#                               Business Name  Rating     Number of Reviews  \
# 0                               poda Studio  rating  4,9 (47 Rezensionen)
# 1                               Pura Studio  rating    5 (60 Rezensionen)
# 2                     Polesition Regensburg  rating  4,9 (27 Rezensionen)
# 3                       Sportheim Abensberg  rating  4,9 (36 Rezensionen)
# 4                      Körperformfabrik GbR  rating   4,9 (3 Rezensionen)
# 5                                  Soultide  rating  4,9 (43 Rezensionen)
# 6   FEEL GOOD FACTORY: Pole • Stretch • Fly  rating       5 (1 Rezension)
# 7                   CSS AERIAL DANCE STUDIO  rating  4,8 (46 Rezensionen)
# 8                                  AIRobics  rating  4,9 (45 Rezensionen)
# 9                      Polemotions Tübingen  rating  4,9 (68 Rezensionen)
# 10                  Polemotions Filderstadt  rating  4,8 (41 Rezensionen)
# 11                 Passionate Pole & Sports  rating    5 (23 Rezensionen)
# 12                              poda Studio  rating  4,9 (47 Rezensionen)
# 13                              Pura Studio  rating    5 (60 Rezensionen)
# 14                              Pura Studio  rating    5 (60 Rezensionen)
# 15                              poda Studio  rating  4,9 (47 Rezensionen)
# 16                          The Pole Jungle  rating   4,9 (7 Rezensionen)
# 17              Yoga and Pole Art by Selina  rating    5 (49 Rezensionen)
# 18                            ST Polestudio  rating  4,7 (11 Rezensionen)
# 19                      Infinity Polesports  rating    5 (29 Rezensionen)
#
#                                            Categories  \
# 0   ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
# 1   ['Yoga', 'Poledance', 'Massage', 'Stretching',...
# 2   ['Pilates', 'Tanzen', 'Poledance', 'Aerial Yog...
# 3   ['Fitness', 'Pilates', 'Poledance', 'Aerial Yo...
# 4   ['Poledance', 'TRX®', 'TRX® Yoga', 'TRX® Suspe...
# 5   ['Yoga', 'Poledance', 'Aerial Yoga', 'Floorwor...
# 6   ['Tanzen', 'Poledance', 'Flexibles Training', ...
# 7   ['Poledance', 'Aerial Yoga', 'Rückenfit', 'Fle...
# 8   ['Yoga', 'Poledance', 'Aerial Yoga', 'Akrobati...
# 9   ['Yoga', 'Poledance', 'Krafttraining', 'Acroyo...
# 10  ['Poledance', 'Krafttraining', 'Stretching', '...
# 11           ['Poledance', 'Akrobatik', 'Stretching']
# 12  ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
# 13  ['Yoga', 'Poledance', 'Massage', 'Stretching',...
# 14  ['Yoga', 'Poledance', 'Massage', 'Stretching',...
# 15  ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
# 16                                      ['Poledance']
# 17  ['Poledance', 'Aerial Yoga', 'Personal Trainin...
# 18                                      ['Poledance']
# 19                                      ['Poledance']
#
#                                               Address
# 0                   Martinstraße 10-12 , 52062 Aachen
# 1            Schaufenberger Straße 61 , 52477 Alsdorf
# 2                    Rebhuhnstraße 4, 93326 Abensberg
# 3                 Von-Hazzi-Straße 7, 93326 Abensberg
# 4                      Hauptstraße 108 , 77855 Achern
# 5                    Süderstraße 159A , 20537 Hamburg
# 6              Holsteinischer Kamp 37 , 22081 Hamburg
# 7           Hummelsbütteler Steindamm , 22851 Hamburg
# 8              Holsteinischer Kamp 58 , 22081 Hamburg
# 9                      Aeulestraße 2 , 72074 Tübingen
# 10             Tübinger Straße 10 , 70794 Filderstadt
# 11   Schöllkopfstraße 40 , 73230 Kirchheim unter Teck
# 12                  Martinstraße 10-12 , 52062 Aachen
# 13           Schaufenberger Straße 61 , 52477 Alsdorf
# 14           Schaufenberger Straße 61 , 52477 Alsdorf
# 15                  Martinstraße 10-12 , 52062 Aachen
# 16                   Volksgartenstraße 19 , 4020 Linz
# 17                      Zum Wingert 10 , 53783 Eitorf
# 18                        Walkmühleweg 47, 75365 Calw
# 19  Martin-Ofner-Straße, 84508 Burgkirchen an der Alz

# %%
# Check for dulpicates & unique values
# all_cities_df["Business Name"].unique()
# Out:
# array(['poda Studio', 'Pura Studio', 'Polesition Regensburg',
#        'Sportheim Abensberg', 'Körperformfabrik GbR', 'Soultide',
#        'FEEL GOOD FACTORY: Pole • Stretch • Fly',
#        'CSS AERIAL DANCE STUDIO', 'AIRobics', 'Polemotions Tübingen',
#        'Polemotions Filderstadt', 'Passionate Pole & Sports',
#        'The Pole Jungle', 'Yoga and Pole Art by Selina', 'ST Polestudio',
#        'Infinity Polesports', 'Vertical - Pole Aerial Dance',
#        'Polefamily-Koblenz', 'TSG Blau-Gold Gießen e.V.', 'Pole Plus',
#        'Pole Circus A + K', 'Polefly Academy', 'Pole Oase', 'POLE LOFT',
#        'POLE HEROES', "Anni's Pole-Dance Uetersen", 'Pole for Soul GbR',
#        'Center of Moving Arts', 'Schönheitstanz Studio', 'X-Step Berlin',
#        'IMA Intentional Movement Academy', 'YH Pole (and) Sports Berlin',
#        'YOGA at Lobe Block', 'Aerial Loft', 'Pole Arts',
#        'Pole Werk by Nelly', 'Flow Academy', 'Polearize',
#        'Ramonas Tanzschmiede', 'Da Becca Flow and Fit', 'Polestructions',
#        'Star Poledance', 'aerialflow',
#        'SECRET MOVES - Athletic Dance Studio', 'Poledancestar',
#        'PoleFitness Leipzig', 'T-Tanzstück Braunschweig',
#        'PoleRoom Braunschweig', 'T-Tanzstück Wolfsburg',
#        'Lift Off – Poledance Academy', 'pure body concepts',
#        'Annaconda Pole & Fitness', 'Yoga Vidya Burgdorf', 'La Belle',
#        'Pole Dance Studio Passion Hannover', 'Pole Paradise',
#        'A heart for poledance', 'Dance & Pole Leverkusen',
#        'Dance & Pole Langenfeld', 'One8dance Studio', 'Poledance-Area',
#        'Dance & Pole Deltawerk', 'Pole and Move Mannheim',
#        'Pole and Move Online Studio', 'Nordpole', 'körpernah',
#        'PoleathletiX', 'The Supergirl Studio', 'Munich Poledance',
#        'Health & Shape München', 'Pole Faction - Pole Dance & Fitness',
#        'Stadtgazellen Bremen', 'VerticalArts Pole & Aerial Fitness',
#        'Polemotions GP', 'Pole Acrobatics', 'BodySoul Studio Düsseldorf',
#        'Pole Land', 'schwerelos Münster', 'Pole Dance Krefeld',
#        'Tanzteufel', 'Glow Sports Club', 'Pole and Move Heidelberg',
#        'Pole Statement', 'Pole Dance Palazzo Sportivo',
#        'Pole and Move Ketsch', 'Polea - Pole and Aerial Dance',
#        'Tanzstudio Michel', 'POLEDANCE NRW',
#        'UpsideDown Studio Bad Homburg',
#        'UpsideDown Studio Friedrichsdorf',
#        'Papillon Dance and Sport Academy', 'Seemannsbraut Poledance',
#        'move Lounge - Pilates, PowerPlate, TRX, Personaltraining',
#        'BALANCE Neumarkt', 'Aerial Art Poledance', "Polerina's Poledance",
#        'Les.Pole', 'Stadtgazellen Studio', 'Janine Hollung',
#        'The Pole Lounge', 'Firstsports - Polefitness', 'Studio Nienke',
#        'CALIPSO STUDIO', 'POLEside', 'Polefriends Halle',
#        'Pole Dance Beauties', 'Luftbonbon', 'PoleCreation',
#        'Pure Motion Kiel', 'Move On! Dance Studio & Polemotions',
#        'Divapole', 'Aerial Circus', 'Body meets Soul Leipzig',
#        'Niyaha Yoga Susann Kind', 'Flexx Arts - Aerial Dance & Fitness',
#        'Poleart_Inspiration', 'MMC DANCE & Event Studio',
#        'Tanzschule Poledance Reutlingen', "Anni's Pole-Dance Neumünster",
#        'KAIFU-LODGE', '-Pole-Aerial-Dance- Souldance',
#        'Flow Fusion Pole-Aerial-Dance Studio', 'Lustforlife.Studio',
#        'PoleWirbel', 'Poleaddict', 'Janardana Yoga',
#        'Dayuma - Pole & Acrobatics', 'LOFT1 BASEL CITY',
#        'SWISS MEGA PARK', 'Aerial Studio', 'Studio AERIS'], dtype=object)

# %%
all_cities_df.sort_values(by="Business Name", ascending=True, inplace=True)

all_cities_df = all_cities_df.drop_duplicates(subset=["Business Name"])
all_cities_df
# Out:
#              City                                       Image Source  \
# 512    Oberasbach  https://files.eversports.com/ab970e44-c9b8-44e...
# 351    Langenfeld              /static/media/icon-white.929e2590.svg
# 210        Glinde  https://files.eversports.com/8cbb2bc4-7116-4df...
# 539     Ottweiler  https://files.eversports.com/22c70aea-bf3a-4ee...
# 382       Leipzig  https://files.eversports.com/78dd0043-6303-452...
# ..            ...                                                ...
# 406  Lüdinghausen  https://files.eversports.com/87abf1f1-e324-4cc...
# 160     Flensburg  https://files.eversports.com/d8b98a8e-e520-49d...
# 146    Eschweiler  https://files.eversports.com/b5fbdb8d-cc1e-44a...
# 71          Brück  https://files.eversports.com/ab1a7da9-e1b3-4e7...
# 649        Senden  https://files.eversports.com/3279e225-badb-4da...
#
#                                          Business Name  Rating  \
# 512                      -Pole-Aerial-Dance- Souldance  rating
# 351                              A heart for poledance  rating
# 210                                           AIRobics  rating
# 539                               Aerial Art Poledance  rating
# 382                                      Aerial Circus  rating
# ..                                                 ...     ...
# 406                                          körpernah  rating
# 160  move Lounge - Pilates, PowerPlate, TRX, Person...  rating
# 146                                        poda Studio  rating
# 71                                  pure body concepts  rating
# 649                                 schwerelos Münster  rating
#
#          Number of Reviews                                         Categories  \
# 512   4,9 (62 Rezensionen)  ['Tanzen', 'Poledance', 'Flexibles Training', ...
# 351   4,9 (15 Rezensionen)                                      ['Poledance']
# 210   4,9 (45 Rezensionen)  ['Yoga', 'Poledance', 'Aerial Yoga', 'Akrobati...
# 539  4,9 (103 Rezensionen)                     ['Poledance', 'Online Klasse']
# 382      5 (2 Rezensionen)  ['Yoga', 'Poledance', 'Krafttraining', 'Akroba...
# ..                     ...                                                ...
# 406     5 (20 Rezensionen)  ['Pilates', 'Yoga', 'Poledance', 'Acroyoga', '...
# 160     5 (21 Rezensionen)  ['Fitness', 'Golf', 'Pilates', 'Personal Train...
# 146   4,9 (47 Rezensionen)  ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
# 71    4,8 (29 Rezensionen)  ['Yoga', 'Hip Hop', 'Poledance', 'Kickboxen', ...
# 649    4,8 (6 Rezensionen)  ['Fitness', 'Tanzen', 'Yoga', 'Poledance', '+ ...
#
#                                          Address
# 512         Turnerheimstraße 45 , 90441 Nürnberg
# 351  Nußbaumer Straße 6, 51469 Bergisch Gladbach
# 210       Holsteinischer Kamp 58 , 22081 Hamburg
# 539         Holzer Straße 98 , 66287 Quierschied
# 382     Zschochersche Straße 79B , 04229 Leipzig
# ..                                           ...
# 406           Ahsener Straße 130 , 45711 Datteln
# 160          Mathildenstraße 2 , 24937 Flensburg
# 146            Martinstraße 10-12 , 52062 Aachen
# 71         Zugspitzstr. 46a , 85591 Vaterstetten
# 649          Weseler Straße 675D , 48163 Münster
#
# [131 rows x 7 columns]

# %%
grouped_df = all_cities_df.groupby("Business Name").size().reset_index(name="Count")

grouped_df
# Out:
#                                          Business Name  Count
# 0                        -Pole-Aerial-Dance- Souldance      1
# 1                                A heart for poledance      1
# 2                                             AIRobics      1
# 3                                 Aerial Art Poledance      1
# 4                                        Aerial Circus      1
# ..                                                 ...    ...
# 126                                          körpernah      1
# 127  move Lounge - Pilates, PowerPlate, TRX, Person...      1
# 128                                        poda Studio      1
# 129                                 pure body concepts      1
# 130                                 schwerelos Münster      1
#
# [131 rows x 2 columns]

# %%
base_url = "https://www.eversports.de/sw/"
city_names = all_cities_df['Business Name']

# Regex for replacing whitespace with hyphens and making lowercase
regex = re.compile(r'\s+')
formatted_names = [regex.sub('-', name.lower()) for name in city_names]

# Create list of URLs
urls = [base_url + name for name in formatted_names]
urls
# Out:
# ['https://www.eversports.de/sw/-pole-aerial-dance--souldance',
#  'https://www.eversports.de/sw/a-heart-for-poledance',
#  'https://www.eversports.de/sw/airobics',
#  'https://www.eversports.de/sw/aerial-art-poledance',
#  'https://www.eversports.de/sw/aerial-circus',
#  'https://www.eversports.de/sw/aerial-loft',
#  'https://www.eversports.de/sw/aerial-studio',
#  'https://www.eversports.de/sw/annaconda-pole-&-fitness',
#  "https://www.eversports.de/sw/anni's-pole-dance-neumünster",
#  "https://www.eversports.de/sw/anni's-pole-dance-uetersen",
#  'https://www.eversports.de/sw/balance-neumarkt',
#  'https://www.eversports.de/sw/body-meets-soul-leipzig',
#  'https://www.eversports.de/sw/bodysoul-studio-düsseldorf',
#  'https://www.eversports.de/sw/calipso-studio',
#  'https://www.eversports.de/sw/css-aerial-dance-studio',
#  'https://www.eversports.de/sw/center-of-moving-arts',
#  'https://www.eversports.de/sw/da-becca-flow-and-fit',
#  'https://www.eversports.de/sw/dance-&-pole-deltawerk',
#  'https://www.eversports.de/sw/dance-&-pole-langenfeld',
#  'https://www.eversports.de/sw/dance-&-pole-leverkusen',
#  'https://www.eversports.de/sw/dayuma---pole-&-acrobatics',
#  'https://www.eversports.de/sw/divapole',
#  'https://www.eversports.de/sw/feel-good-factory:-pole-•-stretch-•-fly',
#  'https://www.eversports.de/sw/firstsports---polefitness',
#  'https://www.eversports.de/sw/flexx-arts---aerial-dance-&-fitness',
#  'https://www.eversports.de/sw/flow-academy',
#  'https://www.eversports.de/sw/flow-fusion-pole-aerial-dance-studio',
#  'https://www.eversports.de/sw/glow-sports-club',
#  'https://www.eversports.de/sw/health-&-shape-münchen',
#  'https://www.eversports.de/sw/ima-intentional-movement-academy',
#  'https://www.eversports.de/sw/infinity-polesports',
#  'https://www.eversports.de/sw/janardana-yoga',
#  'https://www.eversports.de/sw/janine-hollung',
#  'https://www.eversports.de/sw/kaifu-lodge',
#  'https://www.eversports.de/sw/körperformfabrik-gbr',
#  'https://www.eversports.de/sw/loft1-basel-city',
#  'https://www.eversports.de/sw/la-belle',
#  'https://www.eversports.de/sw/les.pole',
#  'https://www.eversports.de/sw/lift-off-–-poledance-academy',
#  'https://www.eversports.de/sw/luftbonbon',
#  'https://www.eversports.de/sw/lustforlife.studio',
#  'https://www.eversports.de/sw/mmc-dance-&-event-studio',
#  'https://www.eversports.de/sw/move-on!-dance-studio-&-polemotions',
#  'https://www.eversports.de/sw/munich-poledance',
#  'https://www.eversports.de/sw/niyaha-yoga-susann-kind',
#  'https://www.eversports.de/sw/nordpole',
#  'https://www.eversports.de/sw/one8dance-studio',
#  'https://www.eversports.de/sw/pole-heroes',
#  'https://www.eversports.de/sw/pole-loft',
#  'https://www.eversports.de/sw/poledance-nrw',
#  'https://www.eversports.de/sw/poleside',
#  'https://www.eversports.de/sw/papillon-dance-and-sport-academy',
#  'https://www.eversports.de/sw/passionate-pole-&-sports',
#  'https://www.eversports.de/sw/pole-acrobatics',
#  'https://www.eversports.de/sw/pole-arts',
#  'https://www.eversports.de/sw/pole-circus-a-+-k',
#  'https://www.eversports.de/sw/pole-dance-beauties',
#  'https://www.eversports.de/sw/pole-dance-krefeld',
#  'https://www.eversports.de/sw/pole-dance-palazzo-sportivo',
#  'https://www.eversports.de/sw/pole-dance-studio-passion-hannover',
#  'https://www.eversports.de/sw/pole-faction---pole-dance-&-fitness',
#  'https://www.eversports.de/sw/pole-land',
#  'https://www.eversports.de/sw/pole-oase',
#  'https://www.eversports.de/sw/pole-paradise',
#  'https://www.eversports.de/sw/pole-plus',
#  'https://www.eversports.de/sw/pole-statement',
#  'https://www.eversports.de/sw/pole-werk-by-nelly',
#  'https://www.eversports.de/sw/pole-and-move-heidelberg',
#  'https://www.eversports.de/sw/pole-and-move-ketsch',
#  'https://www.eversports.de/sw/pole-and-move-mannheim',
#  'https://www.eversports.de/sw/pole-and-move-online-studio',
#  'https://www.eversports.de/sw/pole-for-soul-gbr',
#  'https://www.eversports.de/sw/polecreation',
#  'https://www.eversports.de/sw/polefitness-leipzig',
#  'https://www.eversports.de/sw/poleroom-braunschweig',
#  'https://www.eversports.de/sw/polewirbel',
#  'https://www.eversports.de/sw/polea---pole-and-aerial-dance',
#  'https://www.eversports.de/sw/poleaddict',
#  'https://www.eversports.de/sw/polearize',
#  'https://www.eversports.de/sw/poleart_inspiration',
#  'https://www.eversports.de/sw/poleathletix',
#  'https://www.eversports.de/sw/poledance-area',
#  'https://www.eversports.de/sw/poledancestar',
#  'https://www.eversports.de/sw/polefamily-koblenz',
#  'https://www.eversports.de/sw/polefly-academy',
#  'https://www.eversports.de/sw/polefriends-halle',
#  'https://www.eversports.de/sw/polemotions-filderstadt',
#  'https://www.eversports.de/sw/polemotions-gp',
#  'https://www.eversports.de/sw/polemotions-tübingen',
#  "https://www.eversports.de/sw/polerina's-poledance",
#  'https://www.eversports.de/sw/polesition-regensburg',
#  'https://www.eversports.de/sw/polestructions',
#  'https://www.eversports.de/sw/pura-studio',
#  'https://www.eversports.de/sw/pure-motion-kiel',
#  'https://www.eversports.de/sw/ramonas-tanzschmiede',
#  'https://www.eversports.de/sw/secret-moves---athletic-dance-studio',
#  'https://www.eversports.de/sw/st-polestudio',
#  'https://www.eversports.de/sw/swiss-mega-park',
#  'https://www.eversports.de/sw/schönheitstanz-studio',
#  'https://www.eversports.de/sw/seemannsbraut-poledance',
#  'https://www.eversports.de/sw/soultide',
#  'https://www.eversports.de/sw/sportheim-abensberg',
#  'https://www.eversports.de/sw/stadtgazellen-bremen',
#  'https://www.eversports.de/sw/stadtgazellen-studio',
#  'https://www.eversports.de/sw/star-poledance',
#  'https://www.eversports.de/sw/studio-aeris',
#  'https://www.eversports.de/sw/studio-nienke',
#  'https://www.eversports.de/sw/t-tanzstück-braunschweig',
#  'https://www.eversports.de/sw/t-tanzstück-wolfsburg',
#  'https://www.eversports.de/sw/tsg-blau-gold-gießen-e.v.',
#  'https://www.eversports.de/sw/tanzschule-poledance-reutlingen',
#  'https://www.eversports.de/sw/tanzstudio-michel',
#  'https://www.eversports.de/sw/tanzteufel',
#  'https://www.eversports.de/sw/the-pole-jungle',
#  'https://www.eversports.de/sw/the-pole-lounge',
#  'https://www.eversports.de/sw/the-supergirl-studio',
#  'https://www.eversports.de/sw/upsidedown-studio-bad-homburg',
#  'https://www.eversports.de/sw/upsidedown-studio-friedrichsdorf',
#  'https://www.eversports.de/sw/vertical---pole-aerial-dance',
#  'https://www.eversports.de/sw/verticalarts-pole-&-aerial-fitness',
#  'https://www.eversports.de/sw/x-step-berlin',
#  'https://www.eversports.de/sw/yh-pole-(and)-sports-berlin',
#  'https://www.eversports.de/sw/yoga-at-lobe-block',
#  'https://www.eversports.de/sw/yoga-vidya-burgdorf',
#  'https://www.eversports.de/sw/yoga-and-pole-art-by-selina',
#  'https://www.eversports.de/sw/aerialflow',
#  'https://www.eversports.de/sw/körpernah',
#  'https://www.eversports.de/sw/move-lounge---pilates,-powerplate,-trx,-personaltraining',
#  'https://www.eversports.de/sw/poda-studio',
#  'https://www.eversports.de/sw/pure-body-concepts',
#  'https://www.eversports.de/sw/schwerelos-münster']

# %%
len(urls)
# Out:
# 131

# %%
urls_df = pd.DataFrame(urls)


# urls_df.to_csv("all_pole_studios_germany_urls.csv", index=False)
urls_df
# Out:
#                                                      0
# 0    https://www.eversports.de/sw/-pole-aerial-danc...
# 1    https://www.eversports.de/sw/a-heart-for-poled...
# 2                https://www.eversports.de/sw/airobics
# 3    https://www.eversports.de/sw/aerial-art-poledance
# 4           https://www.eversports.de/sw/aerial-circus
# ..                                                 ...
# 126             https://www.eversports.de/sw/körpernah
# 127  https://www.eversports.de/sw/move-lounge---pil...
# 128           https://www.eversports.de/sw/poda-studio
# 129    https://www.eversports.de/sw/pure-body-concepts
# 130    https://www.eversports.de/sw/schwerelos-münster
#
# [131 rows x 1 columns]

# %%
url_list = urls_df[0].tolist()

# %%
def is_url_valid(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return True
        else:
            return False
    except requests.exceptions.RequestException as e:
        print(f"Error while checking URL: {url}\nError: {e}")
        return False

# %%
valid_urls = []

for index, url in enumerate(url_list):
    print(f"Processing URL {index + 1}/{len(url_list)}: {url}")
    if is_url_valid(url):
        valid_urls.append(url)
        print(f"URL {url} is valid.")
    else:
        print(f"URL {url} is not valid.")
    print("\n")
# Out:
# Processing URL 1/131: https://www.eversports.de/sw/-pole-aerial-dance--souldance
# URL https://www.eversports.de/sw/-pole-aerial-dance--souldance is not valid.
#
#
# Processing URL 2/131: https://www.eversports.de/sw/a-heart-for-poledance
# URL https://www.eversports.de/sw/a-heart-for-poledance is valid.
#
#
# Processing URL 3/131: https://www.eversports.de/sw/airobics
# URL https://www.eversports.de/sw/airobics is valid.
#
#
# Processing URL 4/131: https://www.eversports.de/sw/aerial-art-poledance
# URL https://www.eversports.de/sw/aerial-art-poledance is valid.
#
#
# Processing URL 5/131: https://www.eversports.de/sw/aerial-circus
# URL https://www.eversports.de/sw/aerial-circus is valid.
#
#
# Processing URL 6/131: https://www.eversports.de/sw/aerial-loft
# URL https://www.eversports.de/sw/aerial-loft is valid.
#
#
# Processing URL 7/131: https://www.eversports.de/sw/aerial-studio
# URL https://www.eversports.de/sw/aerial-studio is not valid.
#
#
# Processing URL 8/131: https://www.eversports.de/sw/annaconda-pole-&-fitness
# URL https://www.eversports.de/sw/annaconda-pole-&-fitness is not valid.
#
#
# Processing URL 9/131: https://www.eversports.de/sw/anni's-pole-dance-neumünster
# URL https://www.eversports.de/sw/anni's-pole-dance-neumünster is not valid.
#
#
# Processing URL 10/131: https://www.eversports.de/sw/anni's-pole-dance-uetersen
# URL https://www.eversports.de/sw/anni's-pole-dance-uetersen is not valid.
#
#
# Processing URL 11/131: https://www.eversports.de/sw/balance-neumarkt
# URL https://www.eversports.de/sw/balance-neumarkt is valid.
#
#
# Processing URL 12/131: https://www.eversports.de/sw/body-meets-soul-leipzig
# URL https://www.eversports.de/sw/body-meets-soul-leipzig is valid.
#
#
# Processing URL 13/131: https://www.eversports.de/sw/bodysoul-studio-düsseldorf
# URL https://www.eversports.de/sw/bodysoul-studio-düsseldorf is not valid.
#
#
# Processing URL 14/131: https://www.eversports.de/sw/calipso-studio
# URL https://www.eversports.de/sw/calipso-studio is not valid.
#
#
# Processing URL 15/131: https://www.eversports.de/sw/css-aerial-dance-studio
# URL https://www.eversports.de/sw/css-aerial-dance-studio is valid.
#
#
# Processing URL 16/131: https://www.eversports.de/sw/center-of-moving-arts
# URL https://www.eversports.de/sw/center-of-moving-arts is valid.
#
#
# Processing URL 17/131: https://www.eversports.de/sw/da-becca-flow-and-fit
# URL https://www.eversports.de/sw/da-becca-flow-and-fit is valid.
#
#
# Processing URL 18/131: https://www.eversports.de/sw/dance-&-pole-deltawerk
# URL https://www.eversports.de/sw/dance-&-pole-deltawerk is not valid.
#
#
# Processing URL 19/131: https://www.eversports.de/sw/dance-&-pole-langenfeld
# URL https://www.eversports.de/sw/dance-&-pole-langenfeld is not valid.
#
#
# Processing URL 20/131: https://www.eversports.de/sw/dance-&-pole-leverkusen
# URL https://www.eversports.de/sw/dance-&-pole-leverkusen is not valid.
#
#
# Processing URL 21/131: https://www.eversports.de/sw/dayuma---pole-&-acrobatics
# URL https://www.eversports.de/sw/dayuma---pole-&-acrobatics is not valid.
#
#
# Processing URL 22/131: https://www.eversports.de/sw/divapole
# URL https://www.eversports.de/sw/divapole is valid.
#
#
# Processing URL 23/131: https://www.eversports.de/sw/feel-good-factory:-pole-•-stretch-•-fly
# URL https://www.eversports.de/sw/feel-good-factory:-pole-•-stretch-•-fly is not valid.
#
#
# Processing URL 24/131: https://www.eversports.de/sw/firstsports---polefitness
# URL https://www.eversports.de/sw/firstsports---polefitness is not valid.
#
#
# Processing URL 25/131: https://www.eversports.de/sw/flexx-arts---aerial-dance-&-fitness
# URL https://www.eversports.de/sw/flexx-arts---aerial-dance-&-fitness is not valid.
#
#
# Processing URL 26/131: https://www.eversports.de/sw/flow-academy
# URL https://www.eversports.de/sw/flow-academy is valid.
#
#
# Processing URL 27/131: https://www.eversports.de/sw/flow-fusion-pole-aerial-dance-studio
# URL https://www.eversports.de/sw/flow-fusion-pole-aerial-dance-studio is valid.
#
#
# Processing URL 28/131: https://www.eversports.de/sw/glow-sports-club
# URL https://www.eversports.de/sw/glow-sports-club is valid.
#
#
# Processing URL 29/131: https://www.eversports.de/sw/health-&-shape-münchen
# URL https://www.eversports.de/sw/health-&-shape-münchen is not valid.
#
#
# Processing URL 30/131: https://www.eversports.de/sw/ima-intentional-movement-academy
# URL https://www.eversports.de/sw/ima-intentional-movement-academy is valid.
#
#
# Processing URL 31/131: https://www.eversports.de/sw/infinity-polesports
# URL https://www.eversports.de/sw/infinity-polesports is valid.
#
#
# Processing URL 32/131: https://www.eversports.de/sw/janardana-yoga
# URL https://www.eversports.de/sw/janardana-yoga is not valid.
#
#
# Processing URL 33/131: https://www.eversports.de/sw/janine-hollung
# URL https://www.eversports.de/sw/janine-hollung is valid.
#
#
# Processing URL 34/131: https://www.eversports.de/sw/kaifu-lodge
# URL https://www.eversports.de/sw/kaifu-lodge is valid.
#
#
# Processing URL 35/131: https://www.eversports.de/sw/körperformfabrik-gbr
# URL https://www.eversports.de/sw/körperformfabrik-gbr is not valid.
#
#
# Processing URL 36/131: https://www.eversports.de/sw/loft1-basel-city
# URL https://www.eversports.de/sw/loft1-basel-city is not valid.
#
#
# Processing URL 37/131: https://www.eversports.de/sw/la-belle
# URL https://www.eversports.de/sw/la-belle is valid.
#
#
# Processing URL 38/131: https://www.eversports.de/sw/les.pole
# URL https://www.eversports.de/sw/les.pole is not valid.
#
#
# Processing URL 39/131: https://www.eversports.de/sw/lift-off-–-poledance-academy
# URL https://www.eversports.de/sw/lift-off-–-poledance-academy is not valid.
#
#
# Processing URL 40/131: https://www.eversports.de/sw/luftbonbon
# URL https://www.eversports.de/sw/luftbonbon is valid.
#
#
# Processing URL 41/131: https://www.eversports.de/sw/lustforlife.studio
# URL https://www.eversports.de/sw/lustforlife.studio is not valid.
#
#
# Processing URL 42/131: https://www.eversports.de/sw/mmc-dance-&-event-studio
# URL https://www.eversports.de/sw/mmc-dance-&-event-studio is not valid.
#
#
# Processing URL 43/131: https://www.eversports.de/sw/move-on!-dance-studio-&-polemotions
# URL https://www.eversports.de/sw/move-on!-dance-studio-&-polemotions is not valid.
#
#
# Processing URL 44/131: https://www.eversports.de/sw/munich-poledance
# URL https://www.eversports.de/sw/munich-poledance is valid.
#
#
# Processing URL 45/131: https://www.eversports.de/sw/niyaha-yoga-susann-kind
# URL https://www.eversports.de/sw/niyaha-yoga-susann-kind is valid.
#
#
# Processing URL 46/131: https://www.eversports.de/sw/nordpole
# URL https://www.eversports.de/sw/nordpole is valid.
#
#
# Processing URL 47/131: https://www.eversports.de/sw/one8dance-studio
# URL https://www.eversports.de/sw/one8dance-studio is valid.
#
#
# Processing URL 48/131: https://www.eversports.de/sw/pole-heroes
# URL https://www.eversports.de/sw/pole-heroes is valid.
#
#
# Processing URL 49/131: https://www.eversports.de/sw/pole-loft
# URL https://www.eversports.de/sw/pole-loft is valid.
#
#
# Processing URL 50/131: https://www.eversports.de/sw/poledance-nrw
# URL https://www.eversports.de/sw/poledance-nrw is valid.
#
#
# Processing URL 51/131: https://www.eversports.de/sw/poleside
# URL https://www.eversports.de/sw/poleside is valid.
#
#
# Processing URL 52/131: https://www.eversports.de/sw/papillon-dance-and-sport-academy
# URL https://www.eversports.de/sw/papillon-dance-and-sport-academy is valid.
#
#
# Processing URL 53/131: https://www.eversports.de/sw/passionate-pole-&-sports
# URL https://www.eversports.de/sw/passionate-pole-&-sports is not valid.
#
#
# Processing URL 54/131: https://www.eversports.de/sw/pole-acrobatics
# URL https://www.eversports.de/sw/pole-acrobatics is valid.
#
#
# Processing URL 55/131: https://www.eversports.de/sw/pole-arts
# URL https://www.eversports.de/sw/pole-arts is valid.
#
#
# Processing URL 56/131: https://www.eversports.de/sw/pole-circus-a-+-k
# URL https://www.eversports.de/sw/pole-circus-a-+-k is not valid.
#
#
# Processing URL 57/131: https://www.eversports.de/sw/pole-dance-beauties
# URL https://www.eversports.de/sw/pole-dance-beauties is valid.
#
#
# Processing URL 58/131: https://www.eversports.de/sw/pole-dance-krefeld
# URL https://www.eversports.de/sw/pole-dance-krefeld is valid.
#
#
# Processing URL 59/131: https://www.eversports.de/sw/pole-dance-palazzo-sportivo
# URL https://www.eversports.de/sw/pole-dance-palazzo-sportivo is valid.
#
#
# Processing URL 60/131: https://www.eversports.de/sw/pole-dance-studio-passion-hannover
# URL https://www.eversports.de/sw/pole-dance-studio-passion-hannover is valid.
#
#
# Processing URL 61/131: https://www.eversports.de/sw/pole-faction---pole-dance-&-fitness
# URL https://www.eversports.de/sw/pole-faction---pole-dance-&-fitness is not valid.
#
#
# Processing URL 62/131: https://www.eversports.de/sw/pole-land
# URL https://www.eversports.de/sw/pole-land is valid.
#
#
# Processing URL 63/131: https://www.eversports.de/sw/pole-oase
# URL https://www.eversports.de/sw/pole-oase is valid.
#
#
# Processing URL 64/131: https://www.eversports.de/sw/pole-paradise
# URL https://www.eversports.de/sw/pole-paradise is valid.
#
#
# Processing URL 65/131: https://www.eversports.de/sw/pole-plus
# URL https://www.eversports.de/sw/pole-plus is valid.
#
#
# Processing URL 66/131: https://www.eversports.de/sw/pole-statement
# URL https://www.eversports.de/sw/pole-statement is valid.
#
#
# Processing URL 67/131: https://www.eversports.de/sw/pole-werk-by-nelly
# URL https://www.eversports.de/sw/pole-werk-by-nelly is valid.
#
#
# Processing URL 68/131: https://www.eversports.de/sw/pole-and-move-heidelberg
# URL https://www.eversports.de/sw/pole-and-move-heidelberg is valid.
#
#
# Processing URL 69/131: https://www.eversports.de/sw/pole-and-move-ketsch
# URL https://www.eversports.de/sw/pole-and-move-ketsch is valid.
#
#
# Processing URL 70/131: https://www.eversports.de/sw/pole-and-move-mannheim
# URL https://www.eversports.de/sw/pole-and-move-mannheim is valid.
#
#
# Processing URL 71/131: https://www.eversports.de/sw/pole-and-move-online-studio
# URL https://www.eversports.de/sw/pole-and-move-online-studio is valid.
#
#
# Processing URL 72/131: https://www.eversports.de/sw/pole-for-soul-gbr
# URL https://www.eversports.de/sw/pole-for-soul-gbr is valid.
#
#
# Processing URL 73/131: https://www.eversports.de/sw/polecreation
# URL https://www.eversports.de/sw/polecreation is valid.
#
#
# Processing URL 74/131: https://www.eversports.de/sw/polefitness-leipzig
# URL https://www.eversports.de/sw/polefitness-leipzig is valid.
#
#
# Processing URL 75/131: https://www.eversports.de/sw/poleroom-braunschweig
# URL https://www.eversports.de/sw/poleroom-braunschweig is valid.
#
#
# Processing URL 76/131: https://www.eversports.de/sw/polewirbel
# URL https://www.eversports.de/sw/polewirbel is valid.
#
#
# Processing URL 77/131: https://www.eversports.de/sw/polea---pole-and-aerial-dance
# URL https://www.eversports.de/sw/polea---pole-and-aerial-dance is not valid.
#
#
# Processing URL 78/131: https://www.eversports.de/sw/poleaddict
# URL https://www.eversports.de/sw/poleaddict is valid.
#
#
# Processing URL 79/131: https://www.eversports.de/sw/polearize
# URL https://www.eversports.de/sw/polearize is valid.
#
#
# Processing URL 80/131: https://www.eversports.de/sw/poleart_inspiration
# URL https://www.eversports.de/sw/poleart_inspiration is valid.
#
#
# Processing URL 81/131: https://www.eversports.de/sw/poleathletix
# URL https://www.eversports.de/sw/poleathletix is valid.
#
#
# Processing URL 82/131: https://www.eversports.de/sw/poledance-area
# URL https://www.eversports.de/sw/poledance-area is valid.
#
#
# Processing URL 83/131: https://www.eversports.de/sw/poledancestar
# URL https://www.eversports.de/sw/poledancestar is valid.
#
#
# Processing URL 84/131: https://www.eversports.de/sw/polefamily-koblenz
# URL https://www.eversports.de/sw/polefamily-koblenz is valid.
#
#
# Processing URL 85/131: https://www.eversports.de/sw/polefly-academy
# URL https://www.eversports.de/sw/polefly-academy is valid.
#
#
# Processing URL 86/131: https://www.eversports.de/sw/polefriends-halle
# URL https://www.eversports.de/sw/polefriends-halle is valid.
#
#
# Processing URL 87/131: https://www.eversports.de/sw/polemotions-filderstadt
# URL https://www.eversports.de/sw/polemotions-filderstadt is valid.
#
#
# Processing URL 88/131: https://www.eversports.de/sw/polemotions-gp
# URL https://www.eversports.de/sw/polemotions-gp is valid.
#
#
# Processing URL 89/131: https://www.eversports.de/sw/polemotions-tübingen
# URL https://www.eversports.de/sw/polemotions-tübingen is not valid.
#
#
# Processing URL 90/131: https://www.eversports.de/sw/polerina's-poledance
# URL https://www.eversports.de/sw/polerina's-poledance is not valid.
#
#
# Processing URL 91/131: https://www.eversports.de/sw/polesition-regensburg
# URL https://www.eversports.de/sw/polesition-regensburg is valid.
#
#
# Processing URL 92/131: https://www.eversports.de/sw/polestructions
# URL https://www.eversports.de/sw/polestructions is valid.
#
#
# Processing URL 93/131: https://www.eversports.de/sw/pura-studio
# URL https://www.eversports.de/sw/pura-studio is valid.
#
#
# Processing URL 94/131: https://www.eversports.de/sw/pure-motion-kiel
# URL https://www.eversports.de/sw/pure-motion-kiel is valid.
#
#
# Processing URL 95/131: https://www.eversports.de/sw/ramonas-tanzschmiede
# URL https://www.eversports.de/sw/ramonas-tanzschmiede is valid.
#
#
# Processing URL 96/131: https://www.eversports.de/sw/secret-moves---athletic-dance-studio
# URL https://www.eversports.de/sw/secret-moves---athletic-dance-studio is not valid.
#
#
# Processing URL 97/131: https://www.eversports.de/sw/st-polestudio
# URL https://www.eversports.de/sw/st-polestudio is valid.
#
#
# Processing URL 98/131: https://www.eversports.de/sw/swiss-mega-park
# URL https://www.eversports.de/sw/swiss-mega-park is not valid.
#
#
# Processing URL 99/131: https://www.eversports.de/sw/schönheitstanz-studio
# URL https://www.eversports.de/sw/schönheitstanz-studio is not valid.
#
#
# Processing URL 100/131: https://www.eversports.de/sw/seemannsbraut-poledance
# URL https://www.eversports.de/sw/seemannsbraut-poledance is valid.
#
#
# Processing URL 101/131: https://www.eversports.de/sw/soultide
# URL https://www.eversports.de/sw/soultide is valid.
#
#
# Processing URL 102/131: https://www.eversports.de/sw/sportheim-abensberg
# URL https://www.eversports.de/sw/sportheim-abensberg is valid.
#
#
# Processing URL 103/131: https://www.eversports.de/sw/stadtgazellen-bremen
# URL https://www.eversports.de/sw/stadtgazellen-bremen is valid.
#
#
# Processing URL 104/131: https://www.eversports.de/sw/stadtgazellen-studio
# URL https://www.eversports.de/sw/stadtgazellen-studio is valid.
#
#
# Processing URL 105/131: https://www.eversports.de/sw/star-poledance
# URL https://www.eversports.de/sw/star-poledance is valid.
#
#
# Processing URL 106/131: https://www.eversports.de/sw/studio-aeris
# URL https://www.eversports.de/sw/studio-aeris is not valid.
#
#
# Processing URL 107/131: https://www.eversports.de/sw/studio-nienke
# URL https://www.eversports.de/sw/studio-nienke is not valid.
#
#
# Processing URL 108/131: https://www.eversports.de/sw/t-tanzstück-braunschweig
# URL https://www.eversports.de/sw/t-tanzstück-braunschweig is not valid.
#
#
# Processing URL 109/131: https://www.eversports.de/sw/t-tanzstück-wolfsburg
# URL https://www.eversports.de/sw/t-tanzstück-wolfsburg is not valid.
#
#
# Processing URL 110/131: https://www.eversports.de/sw/tsg-blau-gold-gießen-e.v.
# URL https://www.eversports.de/sw/tsg-blau-gold-gießen-e.v. is not valid.
#
#
# Processing URL 111/131: https://www.eversports.de/sw/tanzschule-poledance-reutlingen
# URL https://www.eversports.de/sw/tanzschule-poledance-reutlingen is valid.
#
#
# Processing URL 112/131: https://www.eversports.de/sw/tanzstudio-michel
# URL https://www.eversports.de/sw/tanzstudio-michel is valid.
#
#
# Processing URL 113/131: https://www.eversports.de/sw/tanzteufel
# URL https://www.eversports.de/sw/tanzteufel is valid.
#
#
# Processing URL 114/131: https://www.eversports.de/sw/the-pole-jungle
# URL https://www.eversports.de/sw/the-pole-jungle is not valid.
#
#
# Processing URL 115/131: https://www.eversports.de/sw/the-pole-lounge
# URL https://www.eversports.de/sw/the-pole-lounge is valid.
#
#
# Processing URL 116/131: https://www.eversports.de/sw/the-supergirl-studio
# URL https://www.eversports.de/sw/the-supergirl-studio is valid.
#
#
# Processing URL 117/131: https://www.eversports.de/sw/upsidedown-studio-bad-homburg
# URL https://www.eversports.de/sw/upsidedown-studio-bad-homburg is valid.
#
#
# Processing URL 118/131: https://www.eversports.de/sw/upsidedown-studio-friedrichsdorf
# URL https://www.eversports.de/sw/upsidedown-studio-friedrichsdorf is valid.
#
#
# Processing URL 119/131: https://www.eversports.de/sw/vertical---pole-aerial-dance
# URL https://www.eversports.de/sw/vertical---pole-aerial-dance is not valid.
#
#
# Processing URL 120/131: https://www.eversports.de/sw/verticalarts-pole-&-aerial-fitness
# URL https://www.eversports.de/sw/verticalarts-pole-&-aerial-fitness is not valid.
#
#
# Processing URL 121/131: https://www.eversports.de/sw/x-step-berlin
# URL https://www.eversports.de/sw/x-step-berlin is valid.
#
#
# Processing URL 122/131: https://www.eversports.de/sw/yh-pole-(and)-sports-berlin
# URL https://www.eversports.de/sw/yh-pole-(and)-sports-berlin is not valid.
#
#
# Processing URL 123/131: https://www.eversports.de/sw/yoga-at-lobe-block
# URL https://www.eversports.de/sw/yoga-at-lobe-block is valid.
#
#
# Processing URL 124/131: https://www.eversports.de/sw/yoga-vidya-burgdorf
# URL https://www.eversports.de/sw/yoga-vidya-burgdorf is valid.
#
#
# Processing URL 125/131: https://www.eversports.de/sw/yoga-and-pole-art-by-selina
# URL https://www.eversports.de/sw/yoga-and-pole-art-by-selina is valid.
#
#
# Processing URL 126/131: https://www.eversports.de/sw/aerialflow
# URL https://www.eversports.de/sw/aerialflow is valid.
#
#
# Processing URL 127/131: https://www.eversports.de/sw/körpernah
# URL https://www.eversports.de/sw/körpernah is not valid.
#
#
# Processing URL 128/131: https://www.eversports.de/sw/move-lounge---pilates,-powerplate,-trx,-personaltraining
# URL https://www.eversports.de/sw/move-lounge---pilates,-powerplate,-trx,-personaltraining is not valid.
#
#
# Processing URL 129/131: https://www.eversports.de/sw/poda-studio
# URL https://www.eversports.de/sw/poda-studio is valid.
#
#
# Processing URL 130/131: https://www.eversports.de/sw/pure-body-concepts
# URL https://www.eversports.de/sw/pure-body-concepts is valid.
#
#
# Processing URL 131/131: https://www.eversports.de/sw/schwerelos-münster
# URL https://www.eversports.de/sw/schwerelos-münster is not valid.

# %%
valid_urls_df = pd.DataFrame(valid_urls, columns=["Valid_URL"])

# assuming the URL column is named 'URL'
valid_urls_df = valid_urls_df.drop_duplicates(subset=['Valid_URL'])
valid_urls_df
# Out:
#                                             Valid_URL
# 0   https://www.eversports.de/sw/a-heart-for-poled...
# 1               https://www.eversports.de/sw/airobics
# 2   https://www.eversports.de/sw/aerial-art-poledance
# 3          https://www.eversports.de/sw/aerial-circus
# 4            https://www.eversports.de/sw/aerial-loft
# ..                                                ...
# 82   https://www.eversports.de/sw/yoga-vidya-burgdorf
# 83  https://www.eversports.de/sw/yoga-and-pole-art...
# 84            https://www.eversports.de/sw/aerialflow
# 85           https://www.eversports.de/sw/poda-studio
# 86    https://www.eversports.de/sw/pure-body-concepts
#
# [87 rows x 1 columns]

# %%
valid_urls_df.to_csv("valid_urls_ger.csv", index=False)
